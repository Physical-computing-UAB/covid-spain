# %%
import pandas as pd

# %%
data = pd.read_csv('./demo_r_mweek3_1_Data.csv')
data.head()
# Out:
#       TIME      GEO    UNIT    SEX                  AGE  Value  \
# 0  2000W01  Belgium  Number  Total                Total  2,814
# 1  2000W01  Belgium  Number  Total  From 75 to 79 years    487
# 2  2000W01  Belgium  Number  Total  From 80 to 84 years    394
# 3  2000W01  Belgium  Number  Total  From 85 to 89 years    481
# 4  2000W01  Belgium  Number  Total     90 years or over    452
#
#   Flag and Footnotes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
data.shape
# Out:
# (160950, 7)

# %%
data_total = data.loc[data.AGE=='Total']
data_total
# Out:
#            TIME                                               GEO    UNIT  \
# 0       2000W01                                           Belgium  Number
# 5       2000W01                                          Bulgaria  Number
# 10      2000W01                                           Czechia  Number
# 15      2000W01                                           Denmark  Number
# 20      2000W01  Germany (until 1990 former territory of the FRG)  Number
# ...         ...                                               ...     ...
# 160925  2020W30                                     Liechtenstein  Number
# 160930  2020W30                                            Norway  Number
# 160935  2020W30                                       Switzerland  Number
# 160940  2020W30                                        Montenegro  Number
# 160945  2020W30                                            Serbia  Number
#
#           SEX    AGE  Value Flag and Footnotes
# 0       Total  Total  2,814                NaN
# 5       Total  Total      :                NaN
# 10      Total  Total      :                NaN
# 15      Total  Total      :                NaN
# 20      Total  Total      :                NaN
# ...       ...    ...    ...                ...
# 160925  Total  Total      :                NaN
# 160930  Total  Total      :                NaN
# 160935  Total  Total      :                NaN
# 160940  Total  Total      :                NaN
# 160945  Total  Total      :                NaN
#
# [32190 rows x 7 columns]

# %%
data_total['year']=data_total.TIME
data_total.year = data_total.year.apply(lambda x:x[0:4])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data_total
# Out:
#            TIME                                               GEO    UNIT  \
# 0       2000W01                                           Belgium  Number
# 5       2000W01                                          Bulgaria  Number
# 10      2000W01                                           Czechia  Number
# 15      2000W01                                           Denmark  Number
# 20      2000W01  Germany (until 1990 former territory of the FRG)  Number
# ...         ...                                               ...     ...
# 160925  2020W30                                     Liechtenstein  Number
# 160930  2020W30                                            Norway  Number
# 160935  2020W30                                       Switzerland  Number
# 160940  2020W30                                        Montenegro  Number
# 160945  2020W30                                            Serbia  Number
#
#           SEX    AGE  Value Flag and Footnotes  year
# 0       Total  Total  2,814                NaN  2000
# 5       Total  Total      :                NaN  2000
# 10      Total  Total      :                NaN  2000
# 15      Total  Total      :                NaN  2000
# 20      Total  Total      :                NaN  2000
# ...       ...    ...    ...                ...   ...
# 160925  Total  Total      :                NaN  2020
# 160930  Total  Total      :                NaN  2020
# 160935  Total  Total      :                NaN  2020
# 160940  Total  Total      :                NaN  2020
# 160945  Total  Total      :                NaN  2020
#
# [32190 rows x 8 columns]

# %%
pais = 'Spain'
data_anual = data_total.drop(columns = ['TIME', 'UNIT', 'SEX', 'AGE', 'Flag and Footnotes'])
data_anual
# Out:
#                                                      GEO  Value  year
# 0                                                Belgium  2,814  2000
# 5                                               Bulgaria      :  2000
# 10                                               Czechia      :  2000
# 15                                               Denmark      :  2000
# 20      Germany (until 1990 former territory of the FRG)      :  2000
# ...                                                  ...    ...   ...
# 160925                                     Liechtenstein      :  2020
# 160930                                            Norway      :  2020
# 160935                                       Switzerland      :  2020
# 160940                                        Montenegro      :  2020
# 160945                                            Serbia      :  2020
#
# [32190 rows x 3 columns]

# %%
cadena='manuel'
cadena.replace('l','xx')
# Out:
# 'manuexx'

# %%
data_anual.Value = data_anual.Value.apply(lambda x:x.replace(',',''))
data_anual.Value = data_anual.Value.apply(lambda x:x.replace(':','0'))
#data_anual = data_total.loc[data_total.GEO==pais].groupby(['GEO','year']).sum()
data_anual.Value = data_anual.Value.astype(int)
data_anual
# Out:
#                                                      GEO  Value  year
# 0                                                Belgium   2814  2000
# 5                                               Bulgaria      0  2000
# 10                                               Czechia      0  2000
# 15                                               Denmark      0  2000
# 20      Germany (until 1990 former territory of the FRG)      0  2000
# ...                                                  ...    ...   ...
# 160925                                     Liechtenstein      0  2020
# 160930                                            Norway      0  2020
# 160935                                       Switzerland      0  2020
# 160940                                        Montenegro      0  2020
# 160945                                            Serbia      0  2020
#
# [32190 rows x 3 columns]

# %%
data_pais
# Out:
#              Value
# GEO   year
# Spain 2000  355073
#       2001  356305
#       2002  365140
#       2003  380924
#       2004  376337
#       2005  383220
#       2006  368166
#       2007  382093
#       2008  381348
#       2009  390740
#       2010  379188
#       2011  384854
#       2012  398739
#       2013  387254
#       2014  392255
#       2015  427851
#       2016  406128
#       2017  420589
#       2018  423994
#       2019  414017
#       2020  284334

# %%
paises = list(data_anual.GEO.unique())
paises
data_pais = data_anual.loc[data_total.GEO==pais].groupby(['GEO','year']).sum().reset_index()
data_pais
# Out:
#         GEO  year   Value
# 0   Belgium  2000  104093
# 1   Belgium  2001  103121
# 2   Belgium  2002  105360
# 3   Belgium  2003  106701
# 4   Belgium  2004  103628
# 5   Belgium  2005  102998
# 6   Belgium  2006  101284
# 7   Belgium  2007  101721
# 8   Belgium  2008  103966
# 9   Belgium  2009  106433
# 10  Belgium  2010  104792
# 11  Belgium  2011  103919
# 12  Belgium  2012  108375
# 13  Belgium  2013  108993
# 14  Belgium  2014  104324
# 15  Belgium  2015  112409
# 16  Belgium  2016  107532
# 17  Belgium  2017  109278
# 18  Belgium  2018  110341
# 19  Belgium  2019  108436
# 20  Belgium  2020   69086

# %%
import matplotlib.pyplot as plt
_,ax=plt.subplots(figsize=(30,10))
for pais in paises:
    data_pais = data_anual.loc[data_total.GEO==pais].groupby(['GEO','year']).sum().reset_index
    ax.plot(data_pais.year, data_pais.Value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4478271b4661> in <module>
#       3 for pais in paises:
#       4     data_pais = data_anual.loc[data_total.GEO==pais].groupby(['GEO','year']).sum()
# ----> 5     ax.plot(data_pais.year, data_pais.Value)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'
